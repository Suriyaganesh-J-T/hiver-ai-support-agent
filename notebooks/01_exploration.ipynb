# %%
import pandas as pd
import numpy as np

print("Hiver Support Agent")
print("Environment is ready!")
print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
# Out:
# Hiver Support Agent
# Environment is ready!
# Pandas: 3.0.5
# NumPy: 2.5.3

# %%
from pathlib import Path
import pandas as pd

sample_path = Path("../data/raw/sample.csv")

df = pd.read_csv(sample_path)

print("Dataset shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())
# Out:
# Dataset shape: (93, 7)
#
# Columns:
# ['tweet_id', 'author_id', 'inbound', 'created_at', 'text', 'response_tweet_id', 'in_response_to_tweet_id']

# %%
pd.set_option("display.max_colwidth", 100)

df.head(10)
# Out:
#    tweet_id     author_id  inbound                      created_at  \
# 0    119237        105834     True  Wed Oct 11 06:55:44 +0000 2017
# 1    119238  ChaseSupport    False  Wed Oct 11 13:25:49 +0000 2017
# 2    119239        105835     True  Wed Oct 11 13:00:09 +0000 2017
# 3    119240  VirginTrains    False  Tue Oct 10 15:16:08 +0000 2017
# 4    119241        105836     True  Tue Oct 10 15:17:21 +0000 2017
# 5    119243  VirginTrains    False  Tue Oct 10 15:25:14 +0000 2017
# 6    119244        105836     True  Tue Oct 10 15:26:44 +0000 2017
# 7    119245  VirginTrains    False  Tue Oct 10 15:33:22 +0000 2017
# 8    119242        105836     True  Tue Oct 10 15:09:00 +0000 2017
# 9    119246  VirginTrains    False  Tue Oct 10 10:13:19 +0000 2017
#
#                                                                                                   text  \
# 0  @AppleSupport causing the reply to be disregarded and the tapped notification under the keyboard...
# ...

# %%
df[[
    "tweet_id",
    "author_id",
    "inbound",
    "text",
    "response_tweet_id",
    "in_response_to_tweet_id"
]].head(10)
# Out:
#    tweet_id     author_id  inbound  \
# 0    119237        105834     True
# 1    119238  ChaseSupport    False
# 2    119239        105835     True
# 3    119240  VirginTrains    False
# 4    119241        105836     True
# 5    119243  VirginTrains    False
# 6    119244        105836     True
# 7    119245  VirginTrains    False
# 8    119242        105836     True
# 9    119246  VirginTrains    False
#
#                                                                                                   text  \
# 0  @AppleSupport causing the reply to be disregarded and the tapped notification under the keyboard...
# 1  @105835 Your business means a lot to us. Please DM your name, zip code and additional details ab...
# 2               @76328 I really hope you all change but I'm sure you won't! Because you don't have to!
# 3  @105836 LiveChat is online at the moment - https://t.co/SY94VtU8Kq or contact 03331 031 031 opti...
# ...

# %%
df["inbound"].value_counts()
# Out:
# inbound
# True     49
# False    44
# Name: count, dtype: int64

# %%
df["inbound"].value_counts(normalize=True) * 100
# Out:
# inbound
# True     52.688172
# False    47.311828
# Name: proportion, dtype: float64

# %%
support_messages = df[df["inbound"] == False]

support_messages["author_id"].value_counts().head(20)
# Out:
# author_id
# AppleSupport       13
# SpotifyCares        8
# Tesco               8
# VirginTrains        4
# British_Airways     3
# ChaseSupport        1
# O2                  1
# comcastcares        1
# sprintcare          1
# SouthwestAir        1
# Ask_Spectrum        1
# HPSupport           1
# UPSHelp             1
# Name: count, dtype: int64

# %%
customer_messages = df[df["inbound"] == True]

customer_messages["author_id"].value_counts().head(20)
# Out:
# author_id
# 105840    4
# 105847    4
# 105855    4
# 105836    3
# 105848    3
# 105856    3
# 105842    2
# 105844    2
# 105850    2
# 105854    2
# 105857    2
# 105834    1
# 105835    1
# 105837    1
# 105838    1
# 105839    1
# 105841    1
# 105843    1
# 82476     1
# 105845    1
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# tweet_id                    0
# author_id                   0
# inbound                     0
# created_at                  0
# text                        0
# response_tweet_id          28
# in_response_to_tweet_id    25
# dtype: int64

# %%
df["created_at"].min(), df["created_at"].max()
# Out:
# ('Thu Oct 12 10:25:35 +0000 2017', 'Wed Oct 11 16:28:34 +0000 2017')

# %%
print("Unique tweets:", df["tweet_id"].nunique())
print("Unique authors:", df["author_id"].nunique())
# Out:
# Unique tweets: 93
# Unique authors: 42

# %%
tweet_id = 1

df[
    (df["tweet_id"] == tweet_id) |
    (df["in_response_to_tweet_id"] == tweet_id) |
    (df["response_tweet_id"].astype(str).str.contains(str(tweet_id), na=False))
][[
    "tweet_id",
    "author_id",
    "inbound",
    "text",
    "response_tweet_id",
    "in_response_to_tweet_id"
]]
# Out:
#     tweet_id     author_id  inbound  \
# 0     119237        105834     True
# 2     119239        105835     True
# 3     119240  VirginTrains    False
# 4     119241        105836     True
# 5     119243  VirginTrains    False
# ..       ...           ...      ...
# 86    119328        105858     True
# 88    119330        105859     True
# 89    119331        105860     True
# 90    119332         Tesco    False
# 91    119333        105861     True
#
#                                                                                                    text  \
# 0   @AppleSupport causing the reply to be disregarded and the tapped notification under the keyboard...
# 2                @76328 I really hope you all change but I'm sure you won't! Because you don't have to!
# 3   @105836 LiveChat is online at the moment - https://t.co/SY94VtU8Kq or contact 03331 031 031 opti...
# 4   @VirginTrains see attached error message. I've tried leaving a voicemail several times in the pa...
# ...

# %%
df["response_tweet_id"].head(20)
# Out:
# 0            119236
# 1               NaN
# 2            119238
# 3            119241
# 4            119243
# 5            119244
# 6            119245
# 7               NaN
# 8            119240
# 9            119242
# 10              NaN
# 11           119248
# 12    119249,119251
# 13              NaN
# 14           119252
# 15           119255
# 16           119257
# 17           119258
# 18           119259
# 19           119260
# Name: response_tweet_id, dtype: str

# %%
df["in_response_to_tweet_id"].head(20)
# Out:
# 0          NaN
# 1     119239.0
# 2          NaN
# 3     119242.0
# 4     119240.0
# 5     119241.0
# 6     119243.0
# 7     119244.0
# 8     119246.0
# 9     119247.0
# 10    119249.0
# 11    119250.0
# 12         NaN
# 13    119253.0
# 14         NaN
# 15    119256.0
# 16    119254.0
# 17    119255.0
# 18    119257.0
# 19    119258.0
# Name: in_response_to_tweet_id, dtype: float64

# %%
df["response_tweet_id"].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df["in_response_to_tweet_id"].dtype
# Out:
# dtype('float64')
